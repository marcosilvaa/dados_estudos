# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosilvaa/dados_estudos/blob/main/An%C3%A1lise_Fundamentalista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Fundamentalista
#
# Consiste em análisar dados das empresas como balanço, faturamento, lucro entre outros. No Brasil temos as fontes oficiais como:
# * [Portal de Dados Abertos CVM](https://dados.cvm.gov.br)
# * [Portal RAD CVM](https://www.rad.cvm.gov.br/ENET/frmConsultaExternaCVM.aspx)
#
# A estrutura dos dados fornecidos pelas fontes oficiais torna mais complexa a extração dos dados, exigindo um maior domínio de manipulação e análise. As diferentes fontes também podem fornecer diferentes valores.
#
# Tamém é possível extrair os dados necessários de fontes não oficiais como as bibliotecas:
#
# * [brFinance](https://github.com/eudesrodrigo/brFinance)
# * [YFinance](https://pypi.org/project/yfinance/)
#
# Outra opção é realizar um WebScraping da área de RI(Relação com Investidor) das empresas.

# %% [markdown]
# ## Informações disponíveis na CVM
#
# Através do portal da CVM podemos extrair diversos tipos de dados, como:
# * Balanço Patrimonial Ativo (BPA)
# * Balanço Patrimonial Passivo (BPP)
# * Demonstração de Fluxo de Caixa - Método Direto (DFC-MD)
# * Demontração de Fluxo de Caixa - Método Indireto (DFC-MI)
# * Demonstração de Resultado Abrangente (DRA)
# * Demonstração de Resultado (DRE)
# * Demonstração de Valor Adicionado (DVA)

# %% [markdown]
# ## Obtendo dados cadastrais das empresas de capital aberto

# %%
import pandas as pd
import numpy as np
import requests

# %%
# link para o CSV com os dados cadastrais das empresas de capital aberto
url = "https://dados.cvm.gov.br/dados/CIA_ABERTA/CAD/DADOS/cad_cia_aberta.csv"

# %%
r = requests.get(url)

# %%
r.text

# %%
# separando texto por linha
linhas = []

for i in r.text.split('\n'):
  linhas.append(i.strip().split(';'))   # strip() remove espaços vazios em excesso, split() separa por ponto e virgula

# %%
linhas

# %%
# transformando em dataframe
data = pd.DataFrame(linhas[1:], columns=linhas[0])

# %%
data.head()

# %% [markdown]
# ##Utilizando compreensão de lista

# %%
linhas = [i.strip().split(';') for i in r.text.split('\n')]

# %%
data = pd.DataFrame(linhas[1:], columns=linhas[0])

# %%
data.head()
# Out:
#              CNPJ_CIA                                       DENOM_SOCIAL  \
# 0  08.773.135/0001-00                                    2W ENERGIA S.A.
# 1  11.396.633/0001-87                        3A COMPANHIA SECURITIZADORA
# 2  12.091.809/0001-55                       3R PETROLEUM OLÉO E GÁS S.A.
# 3  01.547.749/0001-16  521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJU...
# 4  01.851.771/0001-55                               524 PARTICIPAÇOES SA
#
#                          DENOM_COMERC      DT_REG    DT_CONST   DT_CANCEL  \
# 0                       BANCO BESA SA  2020-10-29  2007-03-23
# 1  TRIPLO A  COMPANHIA SECURITIZADORA  2010-03-08  2009-11-03  2015-12-18
# 2                                      2020-11-09  2010-06-08
# 3               521 PARTICIPAÇÕES S/A  1997-07-11  1996-07-30
# 4                524 PARTICIPACOES SA  1997-05-30  1997-04-02
#
#                              MOTIVO_CANCEL        SIT  DT_INI_SIT CD_CVM  ...  \
# 0                                               ATIVO  2020-10-29  25224  ...
# 1  Cancelamento Voluntário - IN CVM 480/09  CANCELADA  2015-12-18  21954  ...
# 2                                               ATIVO  2020-11-09  25291  ...
# 3                                               ATIVO  1997-07-11  16330  ...
# 4                                               ATIVO  1997-05-30  16284  ...
#
#   UF_RESP PAIS_RESP  CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 0      SP             4707000           11  39579400
# 1      RJ            20020000           21  22338867           21  22338867
# 2      RJ            22250180           21  21455555            0         0
# 3
# 4      RJ            20020010           21  38043700            0         0
#
#                    EMAIL_RESP        CNPJ_AUDITOR  \
# 0         ri@2wenergia.com.br  61.366.936/0001-25
# 1  juridico@triploasec.com.br  60.525.706/0001-07
# 2       ri@3rpetroleum.com.br  57.755.217/0001-29
# 3                              18.596.945/0001-83
# 4      gar@opportunity.com.br  40.262.602/0001-31
#
#                                              AUDITOR
# 0          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1  MOORE STEPHENS LIMA LUCCHESI AUDITORES INDEPEN...
# 2                 KPMG AUDITORES INDEPENDENTES LTDA.
# 3  BAKER TILLY 4PARTNERS AUDITORES INDEPENDENTES S/S
# 4                     BKR - LOPES, MACHADO AUDITORES
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Filtrando empresas de acordo com o setor

# %%
# conferindo nomes dos setores presentes no dataset
setor = list(data['SETOR_ATIV'].unique())
setor
# Out:
# ['Construção Civil, Mat. Constr. e Decoração',
#  'Securitização de Recebíveis',
#  'Petróleo e Gás',
#  'Emp. Adm. Part. - Energia Elétrica',
#  'Emp. Adm. Part. - Sem Setor Principal',
#  'Emp. Adm. Participações',
#  'Máquinas, Equipamentos, Veículos e Peças',
#  'Comércio (Atacado e Varejo)',
#  'Arrendamento Mercantil',
#  'Gráficas e Editoras',
#  'Emp. Adm. Part. - Const. Civil, Mat. Const. e Decoração',
#  'Metalurgia e Siderurgia',
#  'Petroquímicos e Borracha',
#  'Agricultura (Açúcar, Álcool e Cana)',
#  'Farmacêutico e Higiene',
#  'Saneamento, Serv. Água e Gás',
#  'Serviços Diversos',
#  'Energia Elétrica',
#  'Seguradoras e Corretoras',
#  'Emp. Adm. Part. - Serviços Transporte e Logística',
#  'Outras Atividades Industriais',
#  'Emp. Adm. Part. - Intermediação Financeira',
#  'Têxtil e Vestuário',
#  'Telecomunicações',
#  'Emp. Adm. Part. - Comércio (Atacado e Varejo)',
#  'Serviços Transporte e Logística',
#  'Emp. Adm. Part. - Seguradoras e Corretoras',
#  'Bancos',
#  'Hospedagem e Turismo',
#  'Bebidas e Fumo',
#  'Serviços Médicos',
#  'Emp. Adm. Part. - Têxtil e Vestuário',
#  'Alimentos',
#  'Emp. Adm. Part. - Educação',
#  'Educação',
#  'Brinquedos e Lazer',
#  'Papel e Celulose',
#  'Extração Mineral',
#  'Emp. Adm. Part. - Telecomunicações',
#  'Emp. Adm. Part. - Serviços médicos',
#  'Emp. Adm. Part. - Comunicação e Informática',
#  'Emp. Adm. Part. - Extração Mineral',
#  'Bolsas de Valores/Mercadorias e Futuros',
#  'Crédito Imobiliário',
#  'Intermediação Financeira',
#  '',
#  'Embalagens',
#  'Emp. Adm. Part. - Crédito Imobiliário',
#  'Comunicação e Informática',
#  'Emp. Adm. Part. - Hospedagem e Turismo',
#  'Comércio Exterior',
#  'Emp. Adm. Part. - Bancos',
#  'Emp. Adm. Part. - Alimentos',
#  'Emp. Adm. Part. - Saneamento, Serv. Água e Gás',
#  'Emp. Adm. Part.-Bolsas de Valores/Mercadorias e Futuros',
#  'Emp. Adm. Part. - Máqs., Equip., Veíc. e Peças',
#  'Emp. Adm. Part. - Metalurgia e Siderurgia',
#  'Emp. Adm. Part. - Petróleo e Gás',
#  'Pesca',
#  'Emp. Adm. Part. - Agricultura (Açúcar, Álcool e Cana)',
#  'Emp. Adm. Part. - Petroquímicos e Borracha',
#  'Emp. Adm. Part. - Arrendamento Mercantil',
#  'Reflorestamento',
#  'Emp. Adm. Part. - Embalagens',
#  'Emp. Adm. Part. - Securitização de Recebíveis',
#  'Emp. Adm. Part. - Farmacêutico e Higiene',
#  'Emp. Adm. Part. - Gráficas e Editoras',
#  'Factoring',
#  'Emp. Adm. Part. - Brinquedos e Lazer',
#  'Emp. Adm. Part. - Papel e Celulose',
#  'Serviços em Geral',
#  None]

# %%
# buscando empresas relacionadas à shoppings 

searchfor = ['MULTIPLAN', 'MALL', 'IGUTAEMI', 'SHOPP']

# criando dataframe -> código busca na coluna denominação social as empresas em que
# o nome contém as palavras chaves determinadas em ´searchfor´ e exclui os dados do tipo  n/a
shoppings = data[data.DENOM_SOCIAL.str.contains('|'.join(searchfor), na = False)]

# %%
shoppings

# %%
# eliminando empresas com status CANCELADA
# filtrando setor shopping com situação de atividade = ATIVO
shoppings_ativos = shoppings[shoppings['SIT'] == 'ATIVO']

# %%
shoppings_ativos

# %% [markdown]
# ---
#
#
#
# Filtrando por CNPJ

# %%
# Buscando empresa através de seu CNPJ
# CNPJ -> JHSF
jhsf = '08.294.224/0001-65'

jhsf_data = data[data['CNPJ_CIA'] == jhsf]
jhsf_data
# Out:
#                 CNPJ_CIA           DENOM_SOCIAL DENOM_COMERC      DT_REG  \
# 1472  08.294.224/0001-65  JHSF PARTICIPAÇÕES SA         JHSF  2007-04-04
#
#         DT_CONST DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT CD_CVM  ...  \
# 1472  2006-06-29                          ATIVO  2007-04-04  20605  ...
#
#      UF_RESP PAIS_RESP CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 1472      SP            5502001           11  37025473           11  37022370
#
#           EMAIL_RESP        CNPJ_AUDITOR  \
# 1472  ri@jhsf.com.br  61.366.936/0001-25
#
#                                         AUDITOR
# 1472  ERNST & YOUNG AUDITORES INDEPENDENTES S/S
#
# [1 rows x 47 columns]

# %%
# lista de CNPJ para realizar uma busca de multiplos endereços
lista_cnpjs = ['05.878.397/0001-32','08.294.224/0001-65', '07.816.890/0001-53', '51.218.147/0001-93', '06.977.751/0001-49']

# %%
lista_filtro = data[data['CNPJ_CIA'].isin(lista_cnpjs)]
lista_filtro
# Out:
#                 CNPJ_CIA                              DENOM_SOCIAL  \
# 71    05.878.397/0001-32      ALIANSCE SONAE SHOPPING CENTERS S.A.
# 72    05.878.397/0001-32      ALIANSCE SONAE SHOPPING CENTERS S.A.
# 379   06.977.751/0001-49                        BR PROPERTIES S.A.
# 380   06.977.751/0001-49                        BR PROPERTIES S.A.
# 1333  51.218.147/0001-93  IGUATEMI EMPRESA DE SHOPPING CENTERS S/A
# 1472  08.294.224/0001-65                     JHSF PARTICIPAÇÕES SA
# 1740  07.816.890/0001-53           MULTIPLAN EMP. IMOBILIARIOS S/A
# 1741  07.816.890/0001-53           MULTIPLAN EMP. IMOBILIARIOS S/A
#
#                                   DENOM_COMERC      DT_REG    DT_CONST  \
# 71        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 72        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 379                         BR PROPERTIES S.A.  2006-01-04  2004-05-26
# 380                         BR PROPERTIES S.A.  2006-01-04  2004-05-26
# 1333  IGUATEMI EMPRESA DE SHOPPING CENTERS S/A  2007-02-02  1979-05-23
# 1472                                      JHSF  2007-04-04  2006-06-29
# 1740                                 MULTIPLAN  2007-07-25  2005-12-30
# 1741                                 MULTIPLAN  2007-07-25  2005-12-30
#
#      DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT CD_CVM  ... UF_RESP PAIS_RESP  \
# 71                            ATIVO  2011-02-01  22357  ...      RJ
# 72                            ATIVO  2011-02-01  22357  ...      RJ
# 379                           ATIVO  2006-01-04  19925  ...      SP
# 380                           ATIVO  2006-01-04  19925  ...      SP
# 1333                          ATIVO  2007-02-02  20494  ...      RJ
# 1472                          ATIVO  2007-04-04  20605  ...      SP
# 1740                          ATIVO  2007-07-25  20982  ...      RJ
# 1741                          ATIVO  2007-07-25  20982  ...      RJ
#
#       CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 71    22431050           21  21767272           21  21767229
# 72    22431050           21  21767272           21  21767229
# 379    4578000           11  32011000           11  32011001
# 380    4578000           11  32011000           11  32011001
# 1333   1455070           11  30377037            0         0
# 1472   5502001           11  37025473           11  37022370
# 1740  22640102           21  30315224           21  30315322
# 1741  22640102           21  30315224           21  30315322
#
#                    EMAIL_RESP        CNPJ_AUDITOR  \
# 71    ri@alianscesonae.com.br  61.366.936/0001-25
# 72    ri@alianscesonae.com.br  61.366.936/0001-25
# 379            ri@brpr.com.br  57.755.217/0001-29
# 380            ri@brpr.com.br  57.755.217/0001-29
# 1333       ri@iguatemi.com.br  49.928.567/0001-11
# 1472           ri@jhsf.com.br  61.366.936/0001-25
# 1740      ri@multiplan.com.br  61.366.936/0001-25
# 1741      ri@multiplan.com.br  61.366.936/0001-25
#
#                                                 AUDITOR
# 71            ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 72            ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 379                  KPMG AUDITORES INDEPENDENTES LTDA.
# 380                  KPMG AUDITORES INDEPENDENTES LTDA.
# 1333  DELOITTE TOUCHE TOHMATSU AUDITORES INDEPENDENT...
# 1472          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1740          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1741          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
#
# [8 rows x 47 columns]

# %%
empresas = list(lista_filtro['CD_CVM'].unique())
empresas
# Out:
# ['22357', '19925', '20494', '20605', '20982']

# %% [markdown]
# # Extração dos demonstrativos trimestrais

# %%
#importando pacotes
#zipfile -> abre arquivos zip 
# io -> lê os arquivos dentro da pasta zip 
import zipfile
import io

# %%
# vamos utilizar o dataset de shoppings ativos 
# realizando a busca através do Código da CVM de cada empresa
empresas = list(shoppings_ativos["CD_CVM"].unique())

# %%
#lista de empresas
empresas
# Out:
# ['22357', '26395', '19909', '21008', '20494', '24473', '20982']

# %% [markdown]
# **Quais demonstrativos são necessários?**
#
# Em "arquivo" determine o tipo de demonstrativo e o ano
#
# Este mesmo arquivo deve estar contido na pasta zip da CVM
#
# O "arquivo" precisa estar na pasta zipada contida em 'link'

# %%
# determinando o nome do arquivo e o link para download do conjunto de arquivos
arquivo = 'itr_cia_aberta_DRE_con_2022.csv'
link = "https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2022.zip"

# %%
# craindo variável que faz o download do conjunto de arquivos
# através da biblioteca request
arquivo_zip = requests.get(link)

# %%
# atrvés da biblioteca ZipFile vamos ler a pasta zip 
zf = zipfile.ZipFile(io.BytesIO(arquivo_zip.content))

# %%
# conferindo o tipo do objeto
zf
# Out:
# <zipfile.ZipFile file=<_io.BytesIO object at 0x7f45c09c1890> mode='r'>

# %%
# selecionando o arquivo a ser utilizado
DRE = zf.open(arquivo)

# %%
# criando lista com os dados selecionados
linhas = DRE.readlines()
linhas

# %%
# utilizando compreensão de listas para melhorar a visualização dos dados obtidos
# strip() -> remove os espaços em branco em excesso 
# decode() -> configurando a codificação do texto 
# ISO-8859-1 é a codificação que reconhece os caracteres em Português
lines = [i.strip().decode('ISO-8859-1') for i in linhas]

# %%
# separando lista para que cada linha contenha as informações de cada empresa
lines = [i.split(';') for i in lines]
lines

# %%
# criando dataframe com os dados baixados do arquivo ZIP 
df = pd.DataFrame(lines[1:], columns = lines[0])

# %%
df.head()
# Out:
#              CNPJ_CIA    DT_REFER VERSAO        DENOM_CIA  CD_CVM  \
# 0  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 1  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 2  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 3  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 4  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 4  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                              DS_CONTA  \
# 0   2021-01-01   2021-03-31     3.01  Receitas de Intermediação Financeira
# 1   2022-01-01   2022-03-31     3.01  Receitas de Intermediação Financeira
# 2   2021-01-01   2021-03-31  3.01.01                      Receita de Juros
# 3   2022-01-01   2022-03-31  3.01.01                      Receita de Juros
# 4   2021-01-01   2021-03-31     3.02  Despesas de Intermediação Financeira
#
#               VL_CONTA ST_CONTA_FIXA
# 0  23354279.0000000000             S
# 1  48490439.0000000000             S
# 2  23354279.0000000000             N
# 3  48490439.0000000000             N
# 4  -9590313.0000000000             S

# %%
DRE_BRMalls = df[df['CD_CVM'] == '019909']

# %%
DRE_BRMalls
# Out:
#                  CNPJ_CIA    DT_REFER VERSAO                    DENOM_CIA  \
# 19336  06.977.745/0001-91  2022-03-31      1  BR MALLS PARTICIPACOES S.A.
# 19337  06.977.745/0001-91  2022-03-31      1  BR MALLS PARTICIPACOES S.A.
# 19338  06.977.745/0001-91  2022-03-31      1  BR MALLS PARTICIPACOES S.A.
# 19339  06.977.745/0001-91  2022-03-31      1  BR MALLS PARTICIPACOES S.A.
# 19340  06.977.745/0001-91  2022-03-31      1  BR MALLS PARTICIPACOES S.A.
# ...                   ...         ...    ...                          ...
# 19535  06.977.745/0001-91  2022-06-30      1  BR MALLS PARTICIPACOES S.A.
# 19536  06.977.745/0001-91  2022-06-30      1  BR MALLS PARTICIPACOES S.A.
# 19537  06.977.745/0001-91  2022-06-30      1  BR MALLS PARTICIPACOES S.A.
# 19538  06.977.745/0001-91  2022-06-30      1  BR MALLS PARTICIPACOES S.A.
# 19539  06.977.745/0001-91  2022-06-30      1  BR MALLS PARTICIPACOES S.A.
#
#        CD_CVM                                   GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 19336  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19337  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19338  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19339  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19340  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# ...       ...                                         ...   ...          ...
# 19535  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19536  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19537  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19538  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 19539  019909  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#       ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA  \
# 19336   PENÚLTIMO   2021-01-01   2021-03-31        3.01
# 19337      ÚLTIMO   2022-01-01   2022-03-31        3.01
# 19338   PENÚLTIMO   2021-01-01   2021-03-31        3.02
# 19339      ÚLTIMO   2022-01-01   2022-03-31        3.02
# 19340   PENÚLTIMO   2021-01-01   2021-03-31        3.03
# ...           ...          ...          ...         ...
# 19535      ÚLTIMO   2022-04-01   2022-06-30     3.99.02
# 19536   PENÚLTIMO   2021-01-01   2021-06-30  3.99.02.01
# 19537   PENÚLTIMO   2021-04-01   2021-06-30  3.99.02.01
# 19538      ÚLTIMO   2022-01-01   2022-06-30  3.99.02.01
# 19539      ÚLTIMO   2022-04-01   2022-06-30  3.99.02.01
#
#                                      DS_CONTA           VL_CONTA ST_CONTA_FIXA
# 19336  Receita de Venda de Bens e/ou Serviços  230691.0000000000             S
# 19337  Receita de Venda de Bens e/ou Serviços  325514.0000000000             S
# 19338   Custo dos Bens e/ou Serviços Vendidos  -26611.0000000000             S
# 19339   Custo dos Bens e/ou Serviços Vendidos  -36730.0000000000             S
# 19340                         Resultado Bruto  204080.0000000000             S
# ...                                       ...                ...           ...
# 19535                  Lucro Diluído por Ação       0.0000000000             N
# 19536                                      ON       0.0000000000             N
# 19537                                      ON       0.0000000000             N
# 19538                                      ON       0.0000000000             N
# 19539                                      ON       0.0000000000             N
#
# [204 rows x 15 columns]

# %% [markdown]
# ## Criação de uma Rotina de Extração

# %%
df.DT_FIM_EXERC.unique()
# Out:
# array(['2021-03-31', '2022-03-31', '2021-06-30', '2022-06-30',
#        '2021-09-30', '2022-09-30', '2021-05-31', '2022-05-31',
#        '2021-08-31', '2022-08-31'], dtype=object)

# %%
df.DT_REFER.unique()
# Out:
# array(['2022-03-31', '2022-06-30', '2022-09-30', '2022-05-31',
#        '2022-08-31'], dtype=object)

# %% [markdown]
# ### Início da Construção do Loop

# %% [markdown]
# Vamos criar um loop que realiza a captura de diversos demonstrativos de uma única vez, e depois filtrar determinadas empresas.
#
# Quando terminado, irá gerar um excel por empresa, onde cada aba será um demonstrativo diferente.
#
# O usuário terá apenas que passar uma lista de empresas que deseja e também uma lista com os demonstrativos.

# %%
# Demonstrativos a serem buscados 
# Balanço Patrimonial Ativo (BPA)
# Demonstração de Fluxo de Caixa - Método Direto (DFC-MD)
# Demonstração de Fluxo de Caixa - Método Indireto (DFC-MI)
# Demonstração de Resultado (DRE)

demonstrativos = ['DFC_MD', 'DFC_MI', 'BPA', 'DRE']

# %%
# instalando biblioteca
# !pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 5.1 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
# impostando biblioteca que cria arquivos no EXCEL com diversas abas
# cada uma contendo um dataframe diferente
import xlsxwriter

# %%
empresas
# Out:
# ['22357', '26395', '19909', '21008', '20494', '24473', '20982']

# %%
import time
start_time = time.time()

import io
import zipfile 

lista_listas = []

a = 0 
 
for j in empresas:

  lista_df = []


  for k in demonstrativos:

    link = "https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2022.zip"

    arquivo_zip = requests.get(link)

    zf = zipfile.ZipFile(io.BytesIO(arquivo_zip.content))

    arquivo = 'itr_cia_aberta_' + str(k) + '_con_2022.csv'

    DRE = zf.open(arquivo)

    linhas = DRE.readlines()

    lines = [i.strip().decode('ISO-8859-1') for i in linhas]

    lines = [i.split(';') for i in lines]

    df = pd.DataFrame(lines[1:], columns = lines[0])

    df['VL_AJUSTADO'] = pd.to_numeric(df['VL_CONTA'])

    filtro = df[df['CD_CVM'] == str(j).zfill(6)]

    lista_df.append(filtro)
    
    print(f'Trabalhando com a empresa {j} e seu demonstrativo {k}. As dimensões são {filtro.shape} ')
    
  lista_listas.append(lista_df)

  #utilizando a biblioteca xlsxwriter 
  writer = pd.ExcelWriter(f'Demonstrativos Empresa {str(j)}.xlsx', engine='xlsxwriter')

  # especifique o que contém no arquivo excel
  # cada linha será responsável por gerar uma aba no arquivo contendo os dados referente à cada demonstrativo
  lista_listas[a][0].to_excel(writer, sheet_name = 'DFC_MD', encoding = 'ISO-8859-1')
  lista_listas[a][1].to_excel(writer, sheet_name = 'DFC_MI', encoding = 'ISO-8859-1')
  lista_listas[a][2].to_excel(writer, sheet_name = 'BPA', encoding = 'ISO-8859-1')
  lista_listas[a][3].to_excel(writer, sheet_name = 'DRE', encoding = 'ISO-8859-1')
  
  # 'a' é o contador do loop das empresas, 
  a += 1 

  print(f'Arquivo Excel com os demonstrativos da empresa {j} já foi exportado \n')

  #fechando arquivo excel 
  writer.save()

print('O tempo de execução desse programa foi de %s segundos ---'%(time.time() - start_time))
# Out:
# Trabalhando com a empresa 22357 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e seu demonstrativo DFC_MI. As dimensões são (282, 16)
# Trabalhando com a empresa 22357 e seu demonstrativo BPA. As dimensões são (280, 15)
# Trabalhando com a empresa 22357 e seu demonstrativo DRE. As dimensões são (180, 16)
# Arquivo Excel com os demonstrativos da empresa 22357 já foi exportado
#
# Trabalhando com a empresa 26395 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 26395 e seu demonstrativo DFC_MI. As dimensões são (204, 16)
# Trabalhando com a empresa 26395 e seu demonstrativo BPA. As dimensões são (362, 15)
# Trabalhando com a empresa 26395 e seu demonstrativo DRE. As dimensões são (310, 16)
# Arquivo Excel com os demonstrativos da empresa 26395 já foi exportado
#
# Trabalhando com a empresa 19909 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19909 e seu demonstrativo DFC_MI. As dimensões são (284, 16)
# Trabalhando com a empresa 19909 e seu demonstrativo BPA. As dimensões são (260, 15)
# Trabalhando com a empresa 19909 e seu demonstrativo DRE. As dimensões são (204, 16)
# Arquivo Excel com os demonstrativos da empresa 19909 já foi exportado
#
# Trabalhando com a empresa 21008 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 21008 e seu demonstrativo DFC_MI. As dimensões são (216, 16)
# Trabalhando com a empresa 21008 e seu demonstrativo BPA. As dimensões são (284, 15)
# Trabalhando com a empresa 21008 e seu demonstrativo DRE. As dimensões são (174, 16)
# Arquivo Excel com os demonstrativos da empresa 21008 já foi exportado
#
# Trabalhando com a empresa 20494 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20494 e seu demonstrativo DFC_MI. As dimensões são (202, 16)
# Trabalhando com a empresa 20494 e seu demonstrativo BPA. As dimensões são (272, 15)
# Trabalhando com a empresa 20494 e seu demonstrativo DRE. As dimensões são (196, 16)
# Arquivo Excel com os demonstrativos da empresa 20494 já foi exportado
#
# Trabalhando com a empresa 24473 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 24473 e seu demonstrativo DFC_MI. As dimensões são (234, 16)
# Trabalhando com a empresa 24473 e seu demonstrativo BPA. As dimensões são (260, 15)
# Trabalhando com a empresa 24473 e seu demonstrativo DRE. As dimensões são (204, 16)
# Arquivo Excel com os demonstrativos da empresa 24473 já foi exportado
#
# Trabalhando com a empresa 20982 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e seu demonstrativo DFC_MI. As dimensões são (364, 16)
# Trabalhando com a empresa 20982 e seu demonstrativo BPA. As dimensões são (390, 15)
# Trabalhando com a empresa 20982 e seu demonstrativo DRE. As dimensões são (374, 16)
# Arquivo Excel com os demonstrativos da empresa 20982 já foi exportado
#
# O tempo de execução desse programa foi de 128.85814690589905 segundos ---
